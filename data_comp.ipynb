# %%
import pandas as pd
import math

# %%
# def compare(df1,df2):

# %%
df1=pd.read_excel("america_solutions_store_mapping.xlsx")
df2=pd.read_excel("india_infra_store_mapping.xlsx")
df1
# Out:
#    Store_ID    Store_Name       City        State   Latitude  Longitude  \
# 0    AMS001   AMS_Store_1      Delhi        Delhi  28.608408  77.172531
# 1    AMS002   AMS_Store_2  Bengaluru    Karnataka  12.967447  77.602103
# 2    AMS003   AMS_Store_3       Pune  Maharashtra  18.492556  73.860073
# 3    AMS004   AMS_Store_4  Ahmedabad      Gujarat  23.012743  72.598340
# 4    AMS005   AMS_Store_5    Kolkata  West Bengal  22.538571  88.332573
# 5    AMS006   AMS_Store_6       Pune  Maharashtra  18.481072  73.837051
# 6    AMS007   AMS_Store_7       Pune  Maharashtra  18.514870  73.858845
# 7    AMS008   AMS_Store_8    Chennai   Tamil Nadu  13.036620  80.244669
# 8    AMS009   AMS_Store_9  Ahmedabad      Gujarat  23.027059  72.564978
# 9    AMS010  AMS_Store_10  Hyderabad    Telangana  17.377375  78.453139
# 10   AMS011  AMS_Store_11  Ahmedabad      Gujarat  23.060165  72.582369
# 11   AMS012  AMS_Store_12     Mumbai  Maharashtra  19.032543  72.840866
# ...

# %%
df2
# Out:
#    Store_ID    Store_Name       City        State   Latitude  Longitude  \
# 0    IIN001   IIN_Store_1  Ahmedabad      Gujarat  22.992385  72.617044
# 1    IIN002   IIN_Store_2  Bengaluru    Karnataka  12.989751  77.602609
# 2    IIN003   IIN_Store_3  Hyderabad    Telangana  17.400806  78.500609
# 3    IIN004   IIN_Store_4    Chennai   Tamil Nadu  13.041166  80.304830
# 4    IIN005   IIN_Store_5     Mumbai  Maharashtra  19.105805  72.889368
# 5    IIN006   IIN_Store_6  Bengaluru    Karnataka  12.983636  77.597864
# 6    IIN007   IIN_Store_7     Mumbai  Maharashtra  19.103097  72.855935
# 7    IIN008   IIN_Store_8  Bengaluru    Karnataka  12.965283  77.547323
# 8    IIN009   IIN_Store_9      Delhi        Delhi  28.592469  77.224082
# 9    IIN010  IIN_Store_10  Bengaluru    Karnataka  12.944342  77.596655
# 10   IIN011  IIN_Store_11  Hyderabad    Telangana  17.337137  78.460810
# 11   IIN012  IIN_Store_12  Bengaluru    Karnataka  12.996770  77.601840
# ...

# %%
def compare(a,b):
    if a>b:
        return a
    elif a<b:
        return b
    else:
        return avg = statistics.mean([12, 34])
print(avg)

# %%
import statistics

# %%
result={}
for i in df1.columns:
    new_list=[]  
    for v1,v2 in zip(df1[i].values,df2[i].values):
            recent=compare(v1, v2)
            new_list.append(recent)
    #df=pd.DataFrame(new_list,columns=[i])
    result[i]=new_list
df=pd.DataFrame(result)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 5
#       3 new_list=[]
#       4 for v1,v2 in zip(df1[i].values,df2[i].values):
# ----> 5         recent=compare(v1, v2)
#       6         new_list.append(recent)
#       7 #df=pd.DataFrame(new_list,columns=[i])
#
# Cell In[27], line 7, in compare(a, b)
#       5     return b
#       6 else:
# ----> 7     return math.avg(a,b)
#
# AttributeError: module 'math' has no attribute 'avg'
